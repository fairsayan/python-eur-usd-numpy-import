# %%
import numpy as np

# %%
def convert(nstr):
    return float(nstr[1:-1])

# %%
dictConversion = dict(zip((2, 3, 4, 5), [convert] * 4))

# %%
a = np.genfromtxt('eur_usd.csv', delimiter = ',', usecols = (2, 3, 4, 5), converters = dictConversion)

# %%
a
# Out:
# array([[1.2018, 1.2116, 1.2127, 1.2016],
#        [1.2118, 1.2126, 1.215 , 1.2102],
#        [1.2123, 1.2091, 1.2135, 1.2055],
#        [1.209 , 1.2086, 1.2093, 1.2056],
#        [1.2083, 1.2093, 1.2118, 1.2061],
#        [1.2099, 1.2015, 1.21  , 1.2012],
#        [1.2015, 1.2035, 1.207 , 1.1993],
#        [1.2033, 1.2037, 1.2045, 1.1998],
#        [1.2033, 1.2036, 1.2081, 1.2022],
#        [1.2033, 1.1984, 1.2049, 1.1942],
#        [1.1983, 1.1967, 1.1996, 1.195 ],
#        [1.1965, 1.198 , 1.1995, 1.1955],
#        [1.1978, 1.1948, 1.1988, 1.1947],
#        [1.1946, 1.1911, 1.1956, 1.1878],
#        [1.1909, 1.1891, 1.192 , 1.187 ],
#        [1.1896, 1.1913, 1.1921, 1.1867],
#        [1.1912, 1.1867, 1.1928, 1.1861],
#        [1.187 , 1.1875, 1.1916, 1.1861],
#        [1.1875, 1.1814, 1.1878, 1.1795],
#        [1.1811, 1.1761, 1.182 , 1.1738],
#        [1.1762, 1.1777, 1.1788, 1.1748],
#        [1.1775, 1.1731, 1.1781, 1.1712],
#        [1.1728, 1.1716, 1.176 , 1.1703],
# ...
